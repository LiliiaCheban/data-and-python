# %% [markdown]
# <a href="https://colab.research.google.com/github/LiliiaCheban/data-and-python/blob/main/Wrangle_the_data1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1 - look at the data
# The Excel file at this URL https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true contains TWO data sheets named county-level and state-level.
#
# In the code cell below, read the county-level sheet into a dataframe called county_level_df and display the contents to see what it looks like.
#
# Then, add more code to read the state-level sheet into a dataframe called state_level_df and display the contents to see what this one looks like.

# %% [markdown]
# Упражнение 1. Просмотрите данные. Файл Excel по этому URL-адресу https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true содержит ДВА листа данных. называются уровнями округа и штата.
#
# В приведенной ниже ячейке кода считайте лист уровня округа в фрейм данных county_level_df и отобразите содержимое, чтобы увидеть, как оно выглядит.
#
# Затем добавьте еще код для чтения листа уровня состояния в фрейм данных с именем state_level_df и отобразите содержимое, чтобы увидеть, как оно выглядит.

# %%
import pandas as pd
county_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "county-level")
state_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "state-level")
def get_summary(df):
  display(df.head())
get_summary(county_level_df)
get_summary(state_level_df)
# Out:
#   State  County  Population  Age  Income
# 0    TX       1          72   34      65
# 1    TX       2          33   42      45
# 2    TX       5          25   23      46
# 3    TX       6          54   36      65
# 4    TX       7          11   42      53
#   State    Pop  Age  Income  Education
# 0    TX  23543   32      54       10.2
# 1    MD  10343   29      69       10.3
# 2    IN   5231   41      35       10.1
# 3    CA  29587   35      67       10.4
# 4    NY  18142   34      78       10.2

# %% [markdown]
# Exercise 2 - combine the two data sets
# Use pd.concat([list of dataframes]) to combine the two dataframes into a new dataframe called income_df, filling missing values with null values.

# %% [markdown]
# Упражнение 2. Объедините два набора данных
# Используйте pd.concat([список фреймов данных]), чтобы объединить два фрейма данных в новый фрейм данных с именем доход_df, заполняя пропущенные значения нулевыми значениями.

# %%
import pandas as pd
county_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "county-level")
state_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "state-level")
def get_summary(df):
  display(df.head())
get_summary(county_level_df)
get_summary(state_level_df)

income_df=pd.concat([county_level_df, state_level_df ])
print(income_df)
# Out:
#   State  County  Population  Age  Income
# 0    TX       1          72   34      65
# 1    TX       2          33   42      45
# 2    TX       5          25   23      46
# 3    TX       6          54   36      65
# 4    TX       7          11   42      53
#   State    Pop  Age  Income  Education
# 0    TX  23543   32      54       10.2
# 1    MD  10343   29      69       10.3
# 2    IN   5231   41      35       10.1
# 3    CA  29587   35      67       10.4
# 4    NY  18142   34      78       10.2
#    State  County  Population  Age  Income      Pop  Education
# 0     TX     1.0        72.0   34      65      NaN        NaN
# 1     TX     2.0        33.0   42      45      NaN        NaN
# 2     TX     5.0        25.0   23      46      NaN        NaN
# 3     TX     6.0        54.0   36      65      NaN        NaN
# 4     TX     7.0        11.0   42      53      NaN        NaN
# 5     TX     8.0        28.0   25      62      NaN        NaN
# 6     TX     9.0        82.0   35      66      NaN        NaN
# 7     TX    10.0         5.0   40      75      NaN        NaN
# 8     MD    11.0        61.0   27      22      NaN        NaN
# 9     MD     2.0         5.0   23      69      NaN        NaN
# 10    MD     4.0        98.0   25      73      NaN        NaN
# 11    MD     3.0        64.0   29      75      NaN        NaN
# 12    MD     2.0        36.0   24      65      NaN        NaN
# 13    MD     1.0        24.0   25      66      NaN        NaN
# 14    MD     5.0        34.0   31      78      NaN        NaN
# 15    MD     6.0        89.0   22      81      NaN        NaN
# 16    MD     8.0        21.0   25      73      NaN        NaN
# 17    MD     7.0        21.0   30      62      NaN        NaN
# 0     TX     NaN         NaN   32      54  23543.0       10.2
# 1     MD     NaN         NaN   29      69  10343.0       10.3
# 2     IN     NaN         NaN   41      35   5231.0       10.1
# 3     CA     NaN         NaN   35      67  29587.0       10.4
# 4     NY     NaN         NaN   34      78  18142.0       10.2

# %% [markdown]
# Exercise 3 - ignoring index to get a new indexing system
# All rows in each dataframe are indexed from 0 to one less than the number of rows. You will have noticed that the concatenation in the previous exercise has kept the indexing from the individual tables.
#
# If we are making a new table it may make sense to create a new set of indices, from 0 to one less than the length of the new table. Do this by adding an extra paramater ignore_index=True. ignore_index is False by default and all original indices are kept.
#
# Combine the dataframes county_level_df and state_level_df into a new dataframe called income_df, adding the parameter ignore_index=True.

# %% [markdown]
# Упражнение 3. Игнорирование индекса для получения новой системы индексирования
# Все строки в каждом кадре данных индексируются от 0 до числа меньше числа строк. Вы заметили, что объединение в предыдущем упражнении сохранило индексацию отдельных таблиц.
#
# Если мы создаем новую таблицу, возможно, имеет смысл создать новый набор индексов от 0 до одного меньше длины новой таблицы. Сделайте это, добавив дополнительный параметр ignore_index=True. ignore_index по умолчанию имеет значение False, и все исходные индексы сохраняются.
#
# Объедините фреймы данных county_level_df и state_level_df в новый фрейм данных с именем Income_df, добавив параметр ignore_index=True.

# %%
import pandas as pd
county_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "county-level")
state_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "state-level")
def get_summary(df):
  display(df.head())
get_summary(county_level_df)
get_summary(state_level_df)

income_df=pd.concat([county_level_df, state_level_df ], ignore_index=True)
print(income_df)
# Out:
#   State  County  Population  Age  Income
# 0    TX       1          72   34      65
# 1    TX       2          33   42      45
# 2    TX       5          25   23      46
# 3    TX       6          54   36      65
# 4    TX       7          11   42      53
#   State    Pop  Age  Income  Education
# 0    TX  23543   32      54       10.2
# 1    MD  10343   29      69       10.3
# 2    IN   5231   41      35       10.1
# 3    CA  29587   35      67       10.4
# 4    NY  18142   34      78       10.2
#    State  County  Population  Age  Income      Pop  Education
# 0     TX     1.0        72.0   34      65      NaN        NaN
# 1     TX     2.0        33.0   42      45      NaN        NaN
# 2     TX     5.0        25.0   23      46      NaN        NaN
# 3     TX     6.0        54.0   36      65      NaN        NaN
# 4     TX     7.0        11.0   42      53      NaN        NaN
# 5     TX     8.0        28.0   25      62      NaN        NaN
# 6     TX     9.0        82.0   35      66      NaN        NaN
# 7     TX    10.0         5.0   40      75      NaN        NaN
# 8     MD    11.0        61.0   27      22      NaN        NaN
# 9     MD     2.0         5.0   23      69      NaN        NaN
# 10    MD     4.0        98.0   25      73      NaN        NaN
# 11    MD     3.0        64.0   29      75      NaN        NaN
# 12    MD     2.0        36.0   24      65      NaN        NaN
# 13    MD     1.0        24.0   25      66      NaN        NaN
# 14    MD     5.0        34.0   31      78      NaN        NaN
# 15    MD     6.0        89.0   22      81      NaN        NaN
# 16    MD     8.0        21.0   25      73      NaN        NaN
# 17    MD     7.0        21.0   30      62      NaN        NaN
# 18    TX     NaN         NaN   32      54  23543.0       10.2
# 19    MD     NaN         NaN   29      69  10343.0       10.3
# 20    IN     NaN         NaN   41      35   5231.0       10.1
# 21    CA     NaN         NaN   35      67  29587.0       10.4
# 22    NY     NaN         NaN   34      78  18142.0       10.2

# %% [markdown]
# Exercise 4 - combine just the columns which are common to both
# Add an extra parameter, join='inner' and combine the dataframes county_level_df and state_level_df into a new dataframe called income_df

# %% [markdown]
# Упражнение 4. Объедините только те столбцы, которые являются общими для обоих.
# Добавьте дополнительный параметр join='inner' и объедините фреймы данных county_level_df и state_level_df в новый фрейм данных с именем доход_df.

# %%
import pandas as pd
county_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "county-level")
state_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "state-level")
income_df=pd.concat([county_level_df[['State','Age','Income']], state_level_df[['State','Age','Income']] ], ignore_index=True)
print(income_df)
# Out:
#    State  Age  Income
# 0     TX   34      65
# 1     TX   42      45
# 2     TX   23      46
# 3     TX   36      65
# 4     TX   42      53
# 5     TX   25      62
# 6     TX   35      66
# 7     TX   40      75
# 8     MD   27      22
# 9     MD   23      69
# 10    MD   25      73
# 11    MD   29      75
# 12    MD   24      65
# 13    MD   25      66
# 14    MD   31      78
# 15    MD   22      81
# 16    MD   25      73
# 17    MD   30      62
# 18    TX   32      54
# 19    MD   29      69
# 20    IN   41      35
# 21    CA   35      67
# 22    NY   34      78

# %% [markdown]
# Exercise 5 - add new rows to the end of the income dataframe
# The sheet income in the Excel data file has 10 further records showing State, Age and Income only, so this table matches the income dataframe exactly.
#
# Read the data from sheet_name income in the same Excel data file into a new dataframe called income_new.
#
# Display the data so that you can inspect it.
#
# Now append this dataframe to the income dataframe to form a new dataframe called income_df_v2. Use the ignore_index=True parameter to reindex.

# %% [markdown]
# Упражнение 5. Добавьте новые строки в конец кадра данных дохода.
# Таблица доходов в файле данных Excel содержит еще 10 записей, показывающих только штат, возраст и доход, поэтому эта таблица точно соответствует фрейму данных дохода.
#
# Считайте данные из дохода имя_листа в том же файле данных Excel в новый фрейм данных с именем доход_новый.
#
# Отобразите данные, чтобы вы могли их проверить.
#
# Теперь добавьте этот фрейм данных к фрейму данных дохода, чтобы сформировать новый фрейм данных с именем доход_df_v2. Используйте параметр ignore_index=True для переиндексации.

# %%
income_new = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", sheet_name='income')
# Display the data so that you can inspect it
print(income_new) # Now append this dataframe to the income dataframe to form a new one called

income_df_v2 = pd.concat([income_df, income_new], ignore_index=True)
print(income_df_v2)
# Out:
#   State  Age  Income
# 0    TX   32      69
# 1    MD   41      35
# 2    IN   32      69
# 3    CA   35      54
# 4    NY   29      78
# 5    TX   35      54
# 6    MD   34      67
# 7    IN   41      35
# 8    CA   29      78
# 9    NY   34      67
#    State  Age  Income
# 0     TX   34      65
# 1     TX   42      45
# 2     TX   23      46
# 3     TX   36      65
# 4     TX   42      53
# 5     TX   25      62
# 6     TX   35      66
# 7     TX   40      75
# 8     MD   27      22
# 9     MD   23      69
# 10    MD   25      73
# 11    MD   29      75
# 12    MD   24      65
# 13    MD   25      66
# 14    MD   31      78
# 15    MD   22      81
# 16    MD   25      73
# 17    MD   30      62
# 18    TX   32      54
# 19    MD   29      69
# 20    IN   41      35
# 21    CA   35      67
# 22    NY   34      78
# 23    TX   32      69
# 24    MD   41      35
# 25    IN   32      69
# 26    CA   35      54
# 27    NY   29      78
# 28    TX   35      54
# 29    MD   34      67
# 30    IN   41      35
# 31    CA   29      78
# 32    NY   34      67

# %% [markdown]
# Exercise 6 - Create a new Pop column in county_level_df
# Looking at the tables country_level_df and state_level_df, each has a column containing data on population. One column is headed Population and the other is headed Pop. Ideally these would be merged into one column and this would minimise the number of NaN entries.
#
# Add a new column called 'Pop' to the county_level_df dataframe which contains a copy of all the values in the 'Population' column (df['new_name'] = df['existing_name'])
# Drop the 'Population' column (df.drop(column name, axis=1) from county_level_df and store the result in a new dataframe called county_level_df_v2
# display the new dataframe

# %% [markdown]
# Упражнение 6. Создайте новый столбец Pop в county_level_df
# Если посмотреть на таблицы Country_level_df и state_level_df, то в каждой из них есть столбец, содержащий данные о населении. Один столбец озаглавлен «Население», а другой — «Население». В идеале их следует объединить в один столбец, и это сведет к минимуму количество записей NaN.
#
# Добавьте новый столбец с именем «Pop» в фрейм данных county_level_df, который содержит копию всех значений в столбце «Население» (df['new_name'] = df['existing_name'])
# Удалите столбец «Население» (df.drop(имя столбца, ось=1) из county_level_df и сохраните результат в новом фрейме данных с именем county_level_df_v2.
# отобразить новый фрейм данных

# %%
import pandas as pd
county_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "county-level")
state_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "state-level")
print(county_level_df.columns)



Pop2=county_level_df['Population'].copy() #copy 'Population' into 'Pop'
print(Pop2)
county_level_df.insert (loc=5, column='Pop', value=Pop2)
print(county_level_df)
county_level_df_v2=county_level_df.drop('Population', axis=1) #drop 'Population'

print('display the new dataframe',county_level_df_v2)
# Out:
# Index(['State', 'County', 'Population', 'Age', 'Income'], dtype='object')
# 0     72
# 1     33
# 2     25
# 3     54
# 4     11
# 5     28
# 6     82
# 7      5
# 8     61
# 9      5
# 10    98
# 11    64
# 12    36
# 13    24
# 14    34
# 15    89
# 16    21
# 17    21
# Name: Population, dtype: int64
#    State  County  Population  Age  Income  Pop
# 0     TX       1          72   34      65   72
# 1     TX       2          33   42      45   33
# 2     TX       5          25   23      46   25
# 3     TX       6          54   36      65   54
# 4     TX       7          11   42      53   11
# 5     TX       8          28   25      62   28
# 6     TX       9          82   35      66   82
# 7     TX      10           5   40      75    5
# 8     MD      11          61   27      22   61
# 9     MD       2           5   23      69    5
# 10    MD       4          98   25      73   98
# 11    MD       3          64   29      75   64
# 12    MD       2          36   24      65   36
# 13    MD       1          24   25      66   24
# 14    MD       5          34   31      78   34
# 15    MD       6          89   22      81   89
# 16    MD       8          21   25      73   21
# 17    MD       7          21   30      62   21
# display the new dataframe    State  County  Age  Income  Pop
# 0     TX       1   34      65   72
# 1     TX       2   42      45   33
# 2     TX       5   23      46   25
# 3     TX       6   36      65   54
# 4     TX       7   42      53   11
# 5     TX       8   25      62   28
# 6     TX       9   35      66   82
# 7     TX      10   40      75    5
# 8     MD      11   27      22   61
# 9     MD       2   23      69    5
# 10    MD       4   25      73   98
# 11    MD       3   29      75   64
# 12    MD       2   24      65   36
# 13    MD       1   25      66   24
# 14    MD       5   31      78   34
# 15    MD       6   22      81   89
# 16    MD       8   25      73   21
# 17    MD       7   30      62   21

# %% [markdown]
# Exercise 7 - clean up the format of the Pop column in state_level_df
# Now that both dataframes hava a Pop column, we should make the data consisent in format for both dataframes.
#
# In county_level_df_v2 the values in the Pop column are in 1000s. In state_level_df the values in the Pop column are actual numbers. Let's convert the state_level_df values to 1000s for consistency. We can do this by performing an operation on a column ( df[column name] = df[column name] / 1000)
#
# make a copy of state_level_df called state_level_df_v2 (use df.copy())
# convert the values in the Pop column of the state_level_df_v2 dataframe to numbers of 1000s from actual numbers, rounding to whole numbers
# convert the values in the 'Pop' column to int64 (df[column name].astype(int))

# %% [markdown]
# Упражнение 7. Очистка формата столбца Pop в state_level_df
# Теперь, когда оба фрейма данных имеют столбец Pop, мы должны сделать данные согласованными по формату для обоих фреймов данных.
#
# В county_level_df_v2 значения в столбце Pop указаны в тысячах. В state_level_df значения в столбце Pop являются фактическими числами. Давайте преобразуем значения state_level_df в 1000 для обеспечения единообразия. Мы можем сделать это, выполнив операцию над столбцом ( df[имя столбца] = df[имя столбца]/1000).
#
# создайте копию state_level_df с именем state_level_df_v2 (используйте df.copy())
# преобразовать значения в столбце Pop кадра данных state_level_df_v2 в числа 1000 из фактических чисел, округлив до целых чисел
# преобразовать значения в столбце «Pop» в int64 (df[имя столбца].astype(int))

# %%
import pandas as pd
county_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "county-level")
state_level_df = pd.read_excel("https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/Income-Data.xlsx?raw=true", "state-level")
print(state_level_df.columns)
pop3=state_level_df['Pop'] = state_level_df['Pop']/1000
print(pop3)
state_level_df_v2=state_level_df.copy()
print(state_level_df_v2)
pop3=state_level_df_v2['Pop'].round(0).astype(int)
state_level_df_v2['Pop']=pop3.replace(pop3)
print(state_level_df_v2)
# Out:
# Index(['State', 'Pop', 'Age', 'Income', 'Education'], dtype='object')
# 0    23.543
# 1    10.343
# 2     5.231
# 3    29.587
# 4    18.142
# Name: Pop, dtype: float64
#   State     Pop  Age  Income  Education
# 0    TX  23.543   32      54       10.2
# 1    MD  10.343   29      69       10.3
# 2    IN   5.231   41      35       10.1
# 3    CA  29.587   35      67       10.4
# 4    NY  18.142   34      78       10.2
#   State  Pop  Age  Income  Education
# 0    TX   24   32      54       10.2
# 1    MD   10   29      69       10.3
# 2    IN    5   41      35       10.1
# 3    CA   30   35      67       10.4
# 4    NY   18   34      78       10.2

# %% [markdown]
# Exercise 8 - combine the two v2 dataframes
# Combine county_level_df_v2 and state_level_df_v2 to create a new dataframe called income_df_v3. The join type should be 'inner' and ignore_index should be True

# %% [markdown]
# Упражнение 8. Объединение двух фреймов данных v2.
# Объедините county_level_df_v2 и state_level_df_v2, чтобы создать новый фрейм данных с именем доход_df_v3. Тип соединения должен быть «внутренним», а ignore_index должен быть True.

# %%
income_df_v3=pd.concat([county_level_df_v2, state_level_df_v2], ignore_index=True)
#income_df_v3 = county_level_df_v2.merge(state_level_df_v2)
print(income_df_v3)
# Out:
#    State  County  Age  Income  Pop  Education
# 0     TX     1.0   34      65   72        NaN
# 1     TX     2.0   42      45   33        NaN
# 2     TX     5.0   23      46   25        NaN
# 3     TX     6.0   36      65   54        NaN
# 4     TX     7.0   42      53   11        NaN
# 5     TX     8.0   25      62   28        NaN
# 6     TX     9.0   35      66   82        NaN
# 7     TX    10.0   40      75    5        NaN
# 8     MD    11.0   27      22   61        NaN
# 9     MD     2.0   23      69    5        NaN
# 10    MD     4.0   25      73   98        NaN
# 11    MD     3.0   29      75   64        NaN
# 12    MD     2.0   24      65   36        NaN
# 13    MD     1.0   25      66   24        NaN
# 14    MD     5.0   31      78   34        NaN
# 15    MD     6.0   22      81   89        NaN
# 16    MD     8.0   25      73   21        NaN
# 17    MD     7.0   30      62   21        NaN
# 18    TX     NaN   32      54   24       10.2
# 19    MD     NaN   29      69   10       10.3
# 20    IN     NaN   41      35    5       10.1
# 21    CA     NaN   35      67   30       10.4
# 22    NY     NaN   34      78   18       10.2

# %% [markdown]
# Exercise 9 - create a function that does all the wrangling
# Create a function called get_income_df() which reads the three data sheets, creates the new versions of county_level_df and state_level_df and combines the new versions.
#
# This function should:
#
# read the three sheets into the dataframes county_level_df, state_level_df and income_new_df
# clean up the Population column of county_level_df so that it has the name Pop
# clean up the Pop column of state_level_df so that it contains values that are whole numbers of 1000s
# combine county_level_df and state_level_df with join='inner', ignoring index
# append income_new_df to the combined dataframe
# SORT the final dataframe on Income in descending order
# return the final dataframe
