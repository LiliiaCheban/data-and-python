# %% [markdown]
# <a href="https://colab.research.google.com/github/LiliiaCheban/data-and-python/blob/main/PandasRetrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datatables = pd.read_html('https://en.wikipedia.org/wiki/Glasgow#Climate')
df = datatables[7]  #Glasgow population data
df
# Out:
#     Year[99]  Population Area (km2) Density (inhabitants/km2)  \
# 0       1300        1500     -[100]                         –
# 1       1600        7000          –                         –
# 2       1791       66000       7.16                      9217
# 3       1831      202426       8.83                     22924
# 4       1846      280000      23.44                     11945
# 5       1872      494824      24.42                     20263
# 6       1891      658073      48.00                     13709
# 7       1901      761712      51.35                     14833
# 8       1912      800000      77.63                     10305
# 9       1921     1034174      77.63                     13321
# 10      1926     1090380     119.42                      9130
# 11      1938     1127825     160.77                      7015
# 12      1946     1050000     160.77                      6531
# 13      1951     1089555     160.77                      6777
# 14      1961     1055017     160.77                      6562
# 15      1971      897485     160.77                      5582
# 16      1981      774068     202.35                      3825
# 17      1991      688600     202.67                      3397
# 18      2001      586710     177.30                      3309
# 19      2011      599650     174.70                      3432
#
#                                          Area changes
# 0                                             Initial
# 1                                             Unknown
# 2   Anderson to James Street/West Nile Street to C...
# 3                           Necropolis and Blythswood
# 4    Burghs of Anderston and Calton/Barony of Gorbals
# 5   Districts of Keppochhill, Alexandra Parade and...
# 6   Burghs of Govanhill, Crosshill, Pollokshields,...
# 7   Bellahouston Park and Craigton. Districts of B...
# 8   Burghs of Govan, Partick, Pollokshaws. Distric...
# 9                                           No change
# 10  Districts of Lambhill, Millerston, Aikenhead, ...
# 11  Districts of Balmuildy, Auchinairn, Cardowan, ...
# 12                                          No change
# 13                                          No change
# 14                                          No change
# 15                                          No change
# 16  Burghs of Rutherglen, Cambuslang, Mount Vernon...
# 17                              Minor boundary change
# 18  Rutherglen and Cambuslang transferred to South...
# 19                              Minor boundary change

# %%
import pandas as pd
datatables = pd.read_html('https://en.wikipedia.org/wiki/Glasgow#Climate')
df = datatables[8]  #Glasgow population data
name=len(datatables)
print('length of article section',name)
df
# Out:
# length of article section 23
#     Glasgow compared[101][102] Glasgow compared[101][102].1  \
# 0               UK Census 2011                      Glasgow
# 1             Total population                       599650
# 2  Population growth 2001–2011                         2.7%
# 3                        White                        88.4%
# 4                        Asian                         8.1%
# 5                        Black                         2.4%
# 6                    Christian                        54.5%
# 7                       Muslim                         5.4%
#
#   Glasgow compared[101][102].2  Glasgow compared[101][102].3
# 0                     Scotland                           NaN
# 1                      5295000                           NaN
# 2                         5.0%                           NaN
# 3                        96.0%                           NaN
# 4                         2.7%                           NaN
# 5                         0.8%                           NaN
# 6                        54.0%                           NaN
# 7                         1.4%                           NaN

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/Paisley-Weather-Data.csv"
df = pd.read_csv(url)
df
# Out:
#      yyyy  mm tmax (degC) tmin (degC) af (days) rain (mm) sun (hours)  \
# 0    1959   1           4          -2        25      40.9        54.1
# 1    1959   2         6.6         2.1        10      41.8        17.8
# 2    1959   3        10.6         4.2         0      50.9        85.7
# 3    1959   4          13         5.2         0      76.3       125.1
# 4    1959   5        18.1         7.9         0        24         222
# ..    ...  ..         ...         ...       ...       ...         ...
# 741  2020  10       12.9*        7.1*        0*    185.3*       76.8*
# 742  2020  11       10.6*        6.0*        0*    142.4*       29.3*
# 743  2020  12        6.9*        2.6*        8*    131.0*       31.6*
# 744  2021   1        4.9*       -0.2*       14*    132.2*       51.0*
# 745  2021   2        7.0*        2.3*        8*    144.3*       58.8*
#
#           status
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 741  Provisional
# 742  Provisional
# 743  Provisional
# 744  Provisional
# 745  Provisional
#
# [746 rows x 8 columns]

# %%
import pandas as pd
url = "https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true"
df = pd.read_excel(url,sheet_name="Industry Migration")
df
# Out:
#      country_code          country_name    wb_income  \
# 0              ae  United Arab Emirates  High income
# 1              ae  United Arab Emirates  High income
# 2              ae  United Arab Emirates  High income
# 3              ae  United Arab Emirates  High income
# 4              ae  United Arab Emirates  High income
# ...           ...                   ...          ...
# 5290           zw              Zimbabwe   Low income
# 5291           zw              Zimbabwe   Low income
# 5292           zw              Zimbabwe   Low income
# 5293           zw              Zimbabwe   Low income
# 5294           zw              Zimbabwe   Low income
#
#                        wb_region isic_section_index  \
# 0     Middle East & North Africa                  C
# 1     Middle East & North Africa                  J
# 2     Middle East & North Africa                  J
# 3     Middle East & North Africa                  J
# 4     Middle East & North Africa                  J
# ...                          ...                ...
# 5290         Sub-Saharan Africa                   B
# 5291         Sub-Saharan Africa                   P
# 5292         Sub-Saharan Africa                   O
# 5293         Sub-Saharan Africa                   J
# 5294         Sub-Saharan Africa                   S
#
#                                       isic_section_name  industry_id  \
# 0                                         Manufacturing            1
# 1                         Information and communication            3
# 2                         Information and communication            4
# 3                         Information and communication            5
# 4                         Information and communication            6
# ...                                                 ...          ...
# 5290                               Mining and quarrying           56
# 5291                                          Education           68
# 5292  Public administration and defence; compulsory ...           74
# 5293                      Information and communication           96
# 5294                           Other service activities          100
#
#                            industry_name  net_per_10K_2015  net_per_10K_2016  \
# 0                        Defense & Space            378.74            127.94
# 1                      Computer Hardware            100.97            358.14
# 2                      Computer Software           1079.36            848.15
# 3                    Computer Networking            401.46            447.39
# 4                               Internet           1840.33           1368.42
# ...                                  ...               ...               ...
# 5290                     Mining & Metals            257.36            187.70
# 5291                    Higher Education            190.84             50.76
# 5292               International Affairs             25.23            -46.12
# 5293   Information Technology & Services             46.65             35.93
# 5294  Non-Profit Organization Management            133.56             88.48
#
#       net_per_10K_2017  net_per_10K_2018  net_per_10K_2019
# 0                 8.20             68.51             49.55
# 1               112.98            149.57            182.22
# 2               596.48            409.18            407.41
# 3               163.99            236.69            188.07
# 4               877.71            852.39            519.40
# ...                ...               ...               ...
# 5290            -17.45             70.60            -18.30
# 5291            -68.74           -234.59           -304.36
# 5292            214.29            311.03            -55.88
# 5293           -142.64           -108.16           -213.82
# 5294              6.96            -39.32            -92.51
#
# [5295 rows x 13 columns]

# %%
import pandas as pd
import requests

url = "https://api.carbonintensity.org.uk/regional"
json_data = requests.get(url).json()['data']
print(json_data)
data_table = json_data[0]
print(data_table)
df = pd.json_normalize(data_table['regions'])
df
# Out:
# [{'from': '2023-11-15T13:30Z', 'to': '2023-11-15T14:00Z', 'regions': [{'regionid': 1, 'dnoregion': 'Scottish Hydro Electric Power Distribution', 'shortname': 'North Scotland', 'intensity': {'forecast': 31, 'index': 'very low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 5.4}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 6.2}, {'fuel': 'nuclear', 'perc': 21.6}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 19.7}, {'fuel': 'solar', 'perc': 0.9}, {'fuel': 'wind', 'perc': 46.3}]}, {'regionid': 2, 'dnoregion': 'SP Distribution', 'shortname': 'South Scotland', 'intensity': {'forecast': 56, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 9.8}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 11.3}, {'fuel': 'nuclear', 'perc': 38.7}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 
'}, 'generationmix': [{'fuel': 'biomass', 'perc': 1.4}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 9.4}, {'fuel': 'nuclear', 'perc': 3.2}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 6.5}, {'fuel': 'solar', 'perc': 7.6}, {'fuel': 'wind', 'perc': 71.8}]}, {'regionid': 7, 'dnoregion': 'WPD South Wales', 'shortname': 'South Wales', 'intensity': {'forecast': 294, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 74.6}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 6.8}, {'fuel': 'wind', 'perc': 18.7}]}, {'regionid': 8, 'dnoregion': 'WPD West Midlands', 'shortname': 'West Midlands', 'intensity': {'forecast': 284, 'index': 'high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 2}, {'fuel': 'coal', 'perc': 6.6}, {'fuel': 'imports', 'perc': 1}, {'fuel': 'gas', 'perc': 55.5}, {'fuel': 'nuclear', 'perc': 2.4}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0.1}, {'fuel': 'solar', 'perc': 8.8}, {'fuel': 'wind', 'perc': 23.5}]}, {'regionid': 9, 'dnoregion': 'WPD East Midlands', 'shortname': 'East Midlands', 'intensity': {'forecast': 339, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 1.9}, {'fuel': 'coal', 'perc': 11.2}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 58.9}, {'fuel': 'nuclear', 'perc': 0.5}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 5.1}, {'fuel': 'wind', 'pe ...
#     regionid                                   dnoregion  \
# 0          1  Scottish Hydro Electric Power Distribution
# 1          2                             SP Distribution
# 2          3                      Electricity North West
# 3          4                              NPG North East
# 4          5                               NPG Yorkshire
# 5          6                                   SP Manweb
# 6          7                             WPD South Wales
# 7          8                           WPD West Midlands
# 8          9                           WPD East Midlands
# 9         10                                   UKPN East
# 10        11                              WPD South West
# 11        12                                   SSE South
# 12        13                                 UKPN London
# 13        14                             UKPN South East
# 14        15                                     England
# 15        16                                    Scotland
# 16        17                                       Wales
# 17        18                                          GB
#
#                    shortname  \
# 0             North Scotland
# 1             South Scotland
# 2         North West England
# 3         North East England
# 4                  Yorkshire
# 5   North Wales & Merseyside
# 6                South Wales
# 7              West Midlands
# 8              East Midlands
# 9               East England
# 10        South West England
# 11             South England
# 12                    London
# 13        South East England
# 14                   England
# 15                  Scotland
# 16                     Wales
# 17                        GB
#
#                                         generationmix  intensity.forecast  \
# 0   [{'fuel': 'biomass', 'perc': 5.4}, {'fuel': 'c...                  31
# 1   [{'fuel': 'biomass', 'perc': 9.8}, {'fuel': 'c...                  56
# 2   [{'fuel': 'biomass', 'perc': 9.9}, {'fuel': 'c...                  45
# 3   [{'fuel': 'biomass', 'perc': 37.2}, {'fuel': '...                 108
# 4   [{'fuel': 'biomass', 'perc': 37.2}, {'fuel': '...                 150
# 5   [{'fuel': 'biomass', 'perc': 1.4}, {'fuel': 'c...                  39
# 6   [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 294
# 7   [{'fuel': 'biomass', 'perc': 2}, {'fuel': 'coa...                 284
# 8   [{'fuel': 'biomass', 'perc': 1.9}, {'fuel': 'c...                 339
# 9   [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                  50
# 10  [{'fuel': 'biomass', 'perc': 0.3}, {'fuel': 'c...                 160
# 11  [{'fuel': 'biomass', 'perc': 0.5}, {'fuel': 'c...                 276
# 12  [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 140
# 13  [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 206
# 14  [{'fuel': 'biomass', 'perc': 8.5}, {'fuel': 'c...                 181
# 15  [{'fuel': 'biomass', 'perc': 2.9}, {'fuel': 'c...                  87
# 16  [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 168
# 17  [{'fuel': 'biomass', 'perc': 7.4}, {'fuel': 'c...                 168
#
#    intensity.index
# 0         very low
# 1              low
# 2              low
# 3              low
# 4         moderate
# 5         very low
# 6        very high
# 7             high
# 8        very high
# 9              low
# 10        moderate
# 11            high
# 12        moderate
# 13            high
# 14        moderate
# 15             low
# 16        moderate
# 17        moderate
