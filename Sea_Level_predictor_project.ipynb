# %% [markdown]
# <a href="https://colab.research.google.com/github/LiliiaCheban/data-and-python/blob/main/Sea_Level_predictor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)
sea_levels.tail(4)
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 130                 8.122973
# 131                 8.053065
# 132                 8.457058
# 133                 8.546648

# %% [markdown]
# Источник данных
# Глобальное среднее абсолютное изменение уровня моря, 1880–2014 гг., предоставлено Агентством по охране окружающей среды США с использованием данных CSIRO, 2015 г.; НОАА, 2015. https://datahub.io/core/sea-level-rise.
#
# Данные описывают годовой уровень моря с 1880 по 2013 год. Показатели корректируются с использованием двух стандартов: Организации Содружества по научным и промышленным исследованиям (CSIRO) и Национального управления океанических и атмосферных исследований (NOAA).
#
# Файл необработанных данных: https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv

# %% [markdown]
# Exercise 1 - Load in the data
# Load in the sea-levels data and have a look, dont forget to check the numerical and technical summaries and get a feel for the dataset

# %% [markdown]
# Упражнение 1. Загрузка данных
# Загрузите данные об уровне моря и посмотрите, не забудьте проверить числовые и технические сводки и почувствовать набор данных.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Display the first few rows of the dataset
print(sea_levels.head())


# Display numerical summaries
print(sea_levels.describe())
print(sea_levels['CSIRO Adjusted Sea Level'].hist())

# Display technical summary
#print(sea_levels.info())
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#               Year  CSIRO Adjusted Sea Level  Lower Error Bound  \
# count   134.000000                134.000000         134.000000
# mean   1946.500000                  3.650341           3.204666
# std      38.826537                  2.485692           2.663781
# min    1880.000000                 -0.440945          -1.346457
# ...

# %% [markdown]
# Exercise 2 - scatter plot
# Create a scatter plot using the "Year" column as the x-axis and the "CSIRO Adjusted Sea Level" column as the y-axis.
#
# hint: try using inline

# %% [markdown]
# Упражнение 2 – диаграмма рассеяния
# Создайте диаграмму рассеяния, используя столбец «Год» в качестве оси X и столбец «Скорректированный уровень моря CSIRO» в качестве оси Y.

# %%
import pandas as pd
import matplotlib.pyplot as plt


url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(sea_levels['Year'], sea_levels['CSIRO Adjusted Sea Level'], color='red', label='Sea Level Data')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('CSIRO Adjusted Sea Level (inches)')
plt.title('Sea Level Over Years')

# Display the plot
plt.show()

# %% [markdown]
# Exercise 3 - Clean the data
# The column NOAA has null values in a number of rows. Clean the data, producing a new dataframe.

# %% [markdown]
# Упражнение 3. Очистка данных
# Столбец NOAA имеет нулевые значения в нескольких строках. Очистите данные, создав новый фрейм данных.

# %%
import pandas as pd


url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Clean the data by dropping rows with null values
cleaned_sea_levels = sea_levels.dropna(subset=['NOAA Adjusted Sea Level'])

# Display the cleaned dataframe
print(cleaned_sea_levels.head())
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 113  1993                  6.291339           6.027559           6.555118
# 114  1994                  6.500000           6.236220           6.763780
# 115  1995                  6.618110           6.354331           6.881890
# 116  1996                  6.787402           6.523622           7.051181
# 117  1997                  7.066929           6.803150           7.330709
#
#      NOAA Adjusted Sea Level
# 113                 6.297493
# 114                 6.310934
# 115                 6.452569
# 116                 6.627631
# 117                 6.733920

# %% [markdown]
# Exercise 3 - plot scatter graph for NOAA adjusted levels

# %% [markdown]
# Упражнение 3. Постройте график разброса для уровней, скорректированных NOAA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Clean the data by dropping rows with null values in the 'NOAA' column
cleaned_sea_levels = sea_levels.dropna(subset=['NOAA Adjusted Sea Level'])

# Plot a scatter graph for NOAA Adjusted Sea Level
plt.scatter(cleaned_sea_levels['Year'], cleaned_sea_levels['NOAA Adjusted Sea Level'])
plt.title('Scatter Plot of NOAA Adjusted Sea Level Over Years')
plt.xlabel('Year')
plt.ylabel('NOAA Adjusted Sea Level')
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise 4 - plot line of best fit for CSIRO
# Use the linregress function from scipi.stats to get the slope and y-intercept of the line of best fit.
# Plot the line of best fit over the top of the scatter plot.
# Make the line go through the year 2050 to predict the sea level rise in 2050.
# (Hint: use numpy to create an array from the first year to 2050 with an increment of 1)

# %% [markdown]
# Упражнение 4. Постройте линию, наиболее подходящую для CSIRO.
# Используйте функцию linregress из scipi.stats, чтобы получить наклон и точку пересечения оси Y линии наилучшего соответствия.
# Постройте линию наилучшего соответствия поверх диаграммы рассеяния.
# Проведите линию через 2050 год, чтобы предсказать повышение уровня моря в 2050 году.
# (Подсказка: используйте numpy для создания массива от первого года до 2050 года с шагом 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np


url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)


# Get the slope and y-intercept of the line of best fit for CSIRO Adjusted Sea Level
regression = linregress(cleaned_sea_levels['Year'], cleaned_sea_levels['CSIRO Adjusted Sea Level'])
slope, intercept = regression.slope, regression.intercept

# Create an extended range for x to predict sea level in 2050
extended_years = np.arange(cleaned_sea_levels['Year'].min(), 2051, 1)

# Predict sea level in 2050 using the line of best fit
predicted_sea_level_2050 = slope * extended_years + intercept

# Plot the scatter graph with line of best fit and prediction for 2050
plt.scatter(cleaned_sea_levels['Year'], cleaned_sea_levels['CSIRO Adjusted Sea Level'], label='CSIRO Adjusted Sea Level')
plt.plot(extended_years, predicted_sea_level_2050, color='red', label='Line of Best Fit (2050 Prediction)')
plt.title('Line of Best Fit for CSIRO Adjusted Sea Level with Prediction for 2050')
plt.xlabel('Year')
plt.ylabel('CSIRO Adjusted Sea Level')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise 5 - plot line of best fit for NOAA
# Use the linregress function from scipi.stats to get the slope and y-intercept of the line of best fit.
# Plot the line of best fit over the top of the scatter plot.
# Make the line go through the year 2030 to predict the sea level rise in 2030
# (Hint: use numpy to create an array from the first year to 2030 with an increment of 1 AND remember to use noaa, which has NaN rows removed)

# %% [markdown]
# Упражнение 5. Постройте линию, наиболее подходящую для NOAA
# Используйте функцию linregress из scipi.stats, чтобы получить наклон и точку пересечения оси Y линии наилучшего соответствия.
# Постройте линию наилучшего соответствия поверх диаграммы рассеяния.
# Проведите линию через 2030 год, чтобы предсказать повышение уровня моря в 2030 году.
# (Подсказка: используйте numpy для создания массива от первого года до 2030 года с шагом 1 И не забудьте использовать noaa, из которого удалены строки NaN)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np


url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Clean the data by dropping rows with null values in the 'NOAA' column
cleaned_sea_levels_noaa = sea_levels.dropna(subset=['NOAA Adjusted Sea Level'])

# Get the slope and y-intercept of the line of best fit for NOAA Adjusted Sea Level
regression_noaa = linregress(cleaned_sea_levels_noaa['Year'], cleaned_sea_levels_noaa['NOAA Adjusted Sea Level'])
slope_noaa, intercept_noaa = regression_noaa.slope, regression_noaa.intercept

# Create an extended range for x to predict sea level in 2030
extended_years_noaa = np.arange(cleaned_sea_levels_noaa['Year'].min(), 2031, 1)

# Predict sea level in 2030 using the line of best fit
predicted_sea_level_2030_noaa = slope_noaa * extended_years_noaa + intercept_noaa

# Plot the scatter graph with line of best fit and prediction for 2030
plt.scatter(cleaned_sea_levels_noaa['Year'], cleaned_sea_levels_noaa['NOAA Adjusted Sea Level'], label='NOAA Adjusted Sea Level')
plt.plot(extended_years_noaa, predicted_sea_level_2030_noaa, color='red', label='Line of Best Fit (2030 Prediction)')
plt.title('Line of Best Fit for NOAA Adjusted Sea Level with Prediction for 2030')
plt.xlabel('Year')
plt.ylabel('NOAA Adjusted Sea Level')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise 6 - shorter range (starting 2000)
# Plot a new line of best fit just using the data from year 2000 through the most recent year in the dataset and using the CSIRO adjusted levels. Make the line also go through the year 2050 to predict the sea level rise in 2050 if the rate of rise continues as it has since the year 2000.

# %% [markdown]
# Упражнение 6 – меньшая дальность (начиная с 2000 г.)
# Постройте новую линию наилучшего соответствия, используя данные с 2000 года по последний год в наборе данных и используя скорректированные уровни CSIRO. Проведите линию также через 2050 год, чтобы спрогнозировать повышение уровня моря в 2050 году, если темпы повышения сохранятся такими же, как с 2000 года.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# Load the sea levels data
url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Extract data for the years 2000 through the most recent year
recent_data = sea_levels[sea_levels['Year'] >= 2000]

# Get slope and y-intercept using linregress
regression = linregress(recent_data['Year'], recent_data['CSIRO Adjusted Sea Level'])

# Create an extended range for x to predict sea level in 2050
extended_range = np.arange(2000, 2051, 1)

# Calculate y values for the extended range
predicted_values = regression.slope * extended_range + regression.intercept

# Plot the scatter plot with line of best fit
plt.scatter(sea_levels['Year'], sea_levels['CSIRO Adjusted Sea Level'], label='Actual Data')
plt.plot(extended_range, predicted_values, label='Line of Best Fit', color='red')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('CSIRO Adjusted Sea Level')
plt.title('Sea Level Rise Prediction')

# Show the plot
plt.legend()
plt.show()

# %% [markdown]
# Exercise 6 - add labels to the axes

# %% [markdown]
# Упражнение 6. Добавление меток к осям

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# Load the sea levels data
url = "https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv"
sea_levels = pd.read_csv(url)

# Extract data for the years 2000 through the most recent year
recent_data = sea_levels[sea_levels['Year'] >= 2000]

# Get slope and y-intercept using linregress
regression = linregress(recent_data['Year'], recent_data['CSIRO Adjusted Sea Level'])

# Create an extended range for x to predict sea level in 2050
extended_range = np.arange(2000, 2051, 1)

# Calculate y values for the extended range
predicted_values = regression.slope * extended_range + regression.intercept

# Plot the scatter plot with line of best fit
plt.scatter(sea_levels['Year'], sea_levels['CSIRO Adjusted Sea Level'], label='Actual Data')
plt.plot(extended_range, predicted_values, label='Line of Best Fit', color='red')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')

# Show the plot
plt.legend()
plt.show()
